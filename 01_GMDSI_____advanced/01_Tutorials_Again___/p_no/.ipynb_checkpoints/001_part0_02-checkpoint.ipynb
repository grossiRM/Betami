# %% [markdown]
# # <img src="./intro_freyberg_model_files/c001.png" style="float: center; width: 75%;  margin-bottom: 0.5em;">

# %%
# !pip install flopy
# Out:
# Requirement already satisfied: flopy in c:\users\gross.desktop-airqm2m\anaconda3\envs\flopy\lib\site-packages (3.8.2)
# Requirement already satisfied: numpy>=1.20.3 in c:\users\gross.desktop-airqm2m\anaconda3\envs\flopy\lib\site-packages (from flopy) (2.2.0)
# Requirement already satisfied: matplotlib>=1.4.0 in c:\users\gross.desktop-airqm2m\anaconda3\envs\flopy\lib\site-packages (from flopy) (3.9.4)
# Requirement already satisfied: pandas>=2.0.0 in c:\users\gross.desktop-airqm2m\anaconda3\envs\flopy\lib\site-packages (from flopy) (2.2.3)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\gross.desktop-airqm2m\anaconda3\envs\flopy\lib\site-packages (from matplotlib>=1.4.0->flopy) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\gross.desktop-airqm2m\anaconda3\envs\flopy\lib\site-packages (from matplotlib>=1.4.0->flopy) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\gross.desktop-airqm2m\anaconda3\envs\flopy\lib\site-packages (from matplotlib>=1.4.0->flopy) (4.55.3)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\gross.desktop-airqm2m\anaconda3\envs\flopy\lib\site-packages (from matplotlib>=1.4.0->flopy) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in c:\users\gross.desktop-airqm2m\anaconda3\envs\flopy\lib\site-packages (from matplotlib>=1.4.0->flopy) (24.2)
# Requirement already satisfied: pillow>=8 in c:\users\gross.desktop-airqm2m\anaconda3\envs\flopy\lib\site-packages (from matplotlib>=1.4.0->flopy) (11.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\gross.desktop-airqm2m\anaconda3\envs\flopy\lib\site-packages (from matplotlib>=1.4.0->flopy) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\gross.desktop-airqm2m\anaconda3\envs\flopy\lib\site-packages (from matplotlib>=1.4.0->flopy) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\gross.desktop-airqm2m\anaconda3\envs\flopy\lib\site-packages (from pandas>=2.0.0->flopy) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\gross.desktop-airqm2m\anaconda3\envs\flopy\lib\site-packages (from pandas>=2.0.0->flopy) (2024.2)
# Requirement already satisfied: six>=1.5 in c:\users\gross.desktop-airqm2m\anaconda3\envs\flopy\lib\site-packages (from python-dateutil>=2.7->matplotlib>=1.4.0->flopy) (1.17.0)

# %%
# !pip install pyemu
# Out:
# Collecting pyemu
#   Using cached pyemu-1.3.8-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: numpy in c:\users\gross.desktop-airqm2m\anaconda3\envs\flopy\lib\site-packages (from pyemu) (2.2.0)
# Requirement already satisfied: pandas in c:\users\gross.desktop-airqm2m\anaconda3\envs\flopy\lib\site-packages (from pyemu) (2.2.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\gross.desktop-airqm2m\anaconda3\envs\flopy\lib\site-packages (from pandas->pyemu) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\gross.desktop-airqm2m\anaconda3\envs\flopy\lib\site-packages (from pandas->pyemu) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\gross.desktop-airqm2m\anaconda3\envs\flopy\lib\site-packages (from pandas->pyemu) (2024.2)
# Requirement already satisfied: six>=1.5 in c:\users\gross.desktop-airqm2m\anaconda3\envs\flopy\lib\site-packages (from python-dateutil>=2.8.2->pandas->pyemu) (1.17.0)
# Using cached pyemu-1.3.8-py3-none-any.whl (347 kB)
# Installing collected packages: pyemu
# Successfully installed pyemu-1.3.8

# %% [markdown]
# part0_02_intro_to_freyberg_model              (01)  c/ s/ dependencies
#
# part1_02_pest_setup
#
# part2_03_prior_monte_carlo

# %%
import os
import shutil
import platform
import pandas as pd
import matplotlib.pyplot as plt
import sys
# sys.path.append(os.path.join("..", "..", "dependencies"))
import flopy
import pyemu
sys.path.insert(0,"..")
import herebedragons as hbd

# %% [markdown]
# ### FOLDER_01 'freyberg_mf6'
# ### FOLDER_02 'models\monthly_model_files_1lyr_newstress'
# ### 01 & 02 ________________________________________________same content ?
# ### PANDAS = Excel

# %%
org_ws = os.path.join('..', '..', 'models', 'monthly_model_files_1lyr_newstress')
sim_ws = os.path.join('freyberg_mf6')

if os.path.exists(sim_ws):
    shutil.rmtree(sim_ws)
shutil.copytree(org_ws, sim_ws)

hbd.prep_bins(sim_ws)

# %%
sim = flopy.mf6.MFSimulation.load(sim_ws=sim_ws, verbosity_level=1)
gwf = sim.get_model()
pyemu.os_utils.run("mf6",cwd=sim_ws)
# Out:
# loading simulation...
#   loading simulation name file...
#   loading tdis package...
#   loading model gwf6...
#     loading package dis...
#     loading package ic...
#     loading package npf...
#     loading package sto...
#     loading package oc...
#     loading package wel...
# Pandas warning occurred while loading data ('freyberg6', 'wel', 'period', 'stress_period_data'):
#     Data File: "E:\00_Betami\01_Tutorials_GMDSI_Work_in_Progress\01_Tutorials_Again___\02a_Beta_part0_02_intro_to_freyberg_model\freyberg_mf6\freyberg6.wel_stress_period_data_1.txt:"
#     Pandas Message: "Length of header or names does not match length of data. This leads to a loss of data with index_col=False."
# Pandas warning occurred while loading data ('freyberg6', 'wel', 'period', 'stress_period_data'):
#     Data File: "E:\00_Betami\01_Tutorials_GMDSI_Work_in_Progress\01_Tutorials_Again___\02a_Beta_part0_02_intro_to_freyberg_model\freyberg_mf6\freyberg6.wel_stress_period_data_2.txt:"
#     Pandas Message: "Length of header or names does not match length of data. This leads to a loss of data with index_col=False."
# Pandas warning occurred while loading data ('freyberg6', 'wel', 'period', 'stress_period_data'):
#     Data File: "E:\00_Betami\01_Tutorials_GMDSI_Work_in_Progress\01_Tutorials_Again___\02a_Beta_part0_02_intro_to_freyberg_model\freyberg_mf6\freyberg6.wel_stress_period_data_3.txt:"
#     Pandas Message: "Length of header or names does not match length of data. This leads to a loss of data with index_col=False."
# Pandas warning occurred while loading data ('freyberg6', 'wel', 'period', 'stress_period_data'):
#     Data File: "E:\00_Betami\01_Tutorials_GMDSI_Work_in_Progress\01_Tutorials_Again___\02a_Beta_part0_02_intro_to_freyberg_model\freyberg_mf6\freyberg6.wel_stress_period_data_4.txt:"
#     Pandas Message: "Length of header or names does not match length of data. This leads to a loss of data with index_col=False."
# Pandas warning occurred while loading data ('freyberg6', 'wel', 'period', 'stress_period_data'):
#     Data File: "E:\00_Betami\01_Tutorials_GMDSI_Work_in_Progress\01_Tutorials_Again___\02a_Beta_part0_02_intro_to_freyberg_model\freyberg_mf6\freyberg6.wel_stress_period_data_5.txt:"
#     Pandas Message: "Length of header or names does not match length of data. This leads to a loss of data with index_col=False."
# Pandas warning occurred while loading data ('freyberg6', 'wel', 'period', 'stress_period_data'):
#     Data File: "E:\00_Betami\01_Tutorials_GMDSI_Work_in_Progress\01_Tutorials_Again___\02a_Beta_part0_02_intro_to_freyberg_model\freyberg_mf6\freyberg6.wel_stress_period_data_6.txt:"
#     Pandas Message: "Length of header or names does not match length of data. This leads to a loss of data with index_col=False."
# Pandas warning occurred while loading data ('freyberg6', 'wel', 'period', 'stress_period_data'):
#     Data File: "E:\00_Betami\01_Tutorials_GMDSI_Work_in_Progress\01_Tutorials_Again___\02a_Beta_part0_02_intro_to_freyberg_model\freyberg_mf6\freyberg6.wel_stress_period_data_7.txt:"
#     Pandas Message: "Length of header or names does not match length of data. This leads to a loss of data with index_col=False."
# Pandas warning occurred while loading data ('freyberg6', 'wel', 'period', 'stress_period_data'):
#     Data File: "E:\00_Betami\01_Tutorials_GMDSI_Work_in_Progress\01_Tutorials_Again___\02a_Beta_part0_02_intro_to_freyberg_model\freyberg_mf6\freyberg6.wel_stress_period_data_8.txt:"
#     Pandas Message: "Length of header or names does not match length of data. This leads to a loss of data with index_col=False."
# Pandas warning occurred while loading data ('freyberg6', 'wel', 'period', 'stress_period_data'):
#     Data File: "E:\00_Betami\01_Tutorials_GMDSI_Work_in_Progress\01_Tutorials_Again___\02a_Beta_part0_02_intro_to_freyberg_model\freyberg_mf6\freyberg6.wel_stress_period_data_9.txt:"
#     Pandas Message: "Length of header or names does not match length of data. This leads to a loss of data with index_col=False."
# Pandas warning occurred while loading data ('freyberg6', 'wel', 'period', 'stress_period_data'):
#     Data File: "E:\00_Betami\01_Tutorials_GMDSI_Work_in_Progress\01_Tutorials_Again___\02a_Beta_part0_02_intro_to_freyberg_model\freyberg_mf6\freyberg6.wel_stress_period_data_10.txt:"
#     Pandas Message: "Length of header or names does not match length of data. This leads to a loss of data with index_col=False."
# Pandas warning occurred while loading data ('freyberg6', 'wel', 'period', 'stress_period_data'):
#     Data File: "E:\00_Betami\01_Tutorials_GMDSI_Work_in_Progress\01_Tutorials_Again___\02a_Beta_part0_02_intro_to_freyberg_model\freyberg_mf6\freyberg6.wel_stress_period_data_11.txt:"
#     Pandas Message: "Length of header or names does not match length of data. This leads to a loss of data with index_col=False."
# Pandas warning occurred while loading data ('freyberg6', 'wel', 'period', 'stress_period_data'):
#     Data File: "E:\00_Betami\01_Tutorials_GMDSI_Work_in_Progress\01_Tutorials_Again___\02a_Beta_part0_02_intro_to_freyberg_model\freyberg_mf6\freyberg6.wel_stress_period_data_12.txt:"
#     Pandas Message: "Length of header or names does not match length of data. This leads to a loss of data with index_col=False."
# Pandas warning occurred while loading data ('freyberg6', 'wel', 'period', 'stress_period_data'):
#     Data File: "E:\00_Betami\01_Tutorials_GMDSI_Work_in_Progress\01_Tutorials_Again___\02a_Beta_part0_02_intro_to_freyberg_model\freyberg_mf6\freyberg6.wel_stress_period_data_13.txt:"
#     Pandas Message: "Length of header or names does not match length of data. This leads to a loss of data with index_col=False."
# Pandas warning occurred while loading data ('freyberg6', 'wel', 'period', 'stress_period_data'):
#     Data File: "E:\00_Betami\01_Tutorials_GMDSI_Work_in_Progress\01_Tutorials_Again___\02a_Beta_part0_02_intro_to_freyberg_model\freyberg_mf6\freyberg6.wel_stress_period_data_14.txt:"
#     Pandas Message: "Length of header or names does not match length of data. This leads to a loss of data with index_col=False."
# Pandas warning occurred while loading data ('freyberg6', 'wel', 'period', 'stress_period_data'):
#     Data File: "E:\00_Betami\01_Tutorials_GMDSI_Work_in_Progress\01_Tutorials_Again___\02a_Beta_part0_02_intro_to_freyberg_model\freyberg_mf6\freyberg6.wel_stress_period_data_15.txt:"
#     Pandas Message: "Length of header or names does not match length of data. This leads to a loss of data with index_col=False."
# Pandas warning occurred while loading data ('freyberg6', 'wel', 'period', 'stress_period_data'):
#     Data File: "E:\00_Betami\01_Tutorials_GMDSI_Work_in_Progress\01_Tutorials_Again___\02a_Beta_part0_02_intro_to_freyberg_model\freyberg_mf6\freyberg6.wel_stress_period_data_16.txt:"
#     Pandas Message: "Length of header or names does not match length of data. This leads to a loss of data with index_col=False."
# Pandas warning occurred while loading data ('freyberg6', 'wel', 'period', 'stress_period_data'):
#     Data File: "E:\00_Betami\01_Tutorials_GMDSI_Work_in_Progress\01_Tutorials_Again___\02a_Beta_part0_02_intro_to_freyberg_model\freyberg_mf6\freyberg6.wel_stress_period_data_17.txt:"
#     Pandas Message: "Length of header or names does not match length of data. This leads to a loss of data with index_col=False."
# Pandas warning occurred while loading data ('freyberg6', 'wel', 'period', 'stress_period_data'):
#     Data File: "E:\00_Betami\01_Tutorials_GMDSI_Work_in_Progress\01_Tutorials_Again___\02a_Beta_part0_02_intro_to_freyberg_model\freyberg_mf6\freyberg6.wel_stress_period_data_18.txt:"
#     Pandas Message: "Length of header or names does not match length of data. This leads to a loss of data with index_col=False."
# Pandas warning occurred while loading data ('freyberg6', 'wel', 'period', 'stress_period_data'):
#     Data File: "E:\00_Betami\01_Tutorials_GMDSI_Work_in_Progress\01_Tutorials_Again___\02a_Beta_part0_02_intro_to_freyberg_model\freyberg_mf6\freyberg6.wel_stress_period_data_19.txt:"
#     Pandas Message: "Length of header or names does not match length of data. This leads to a loss of data with index_col=False."
# Pandas warning occurred while loading data ('freyberg6', 'wel', 'period', 'stress_period_data'):
#     Data File: "E:\00_Betami\01_Tutorials_GMDSI_Work_in_Progress\01_Tutorials_Again___\02a_Beta_part0_02_intro_to_freyberg_model\freyberg_mf6\freyberg6.wel_stress_period_data_20.txt:"
#     Pandas Message: "Length of header or names does not match length of data. This leads to a loss of data with index_col=False."
# Pandas warning occurred while loading data ('freyberg6', 'wel', 'period', 'stress_period_data'):
#     Data File: "E:\00_Betami\01_Tutorials_GMDSI_Work_in_Progress\01_Tutorials_Again___\02a_Beta_part0_02_intro_to_freyberg_model\freyberg_mf6\freyberg6.wel_stress_period_data_21.txt:"
#     Pandas Message: "Length of header or names does not match length of data. This leads to a loss of data with index_col=False."
# Pandas warning occurred while loading data ('freyberg6', 'wel', 'period', 'stress_period_data'):
#     Data File: "E:\00_Betami\01_Tutorials_GMDSI_Work_in_Progress\01_Tutorials_Again___\02a_Beta_part0_02_intro_to_freyberg_model\freyberg_mf6\freyberg6.wel_stress_period_data_22.txt:"
#     Pandas Message: "Length of header or names does not match length of data. This leads to a loss of data with index_col=False."
# Pandas warning occurred while loading data ('freyberg6', 'wel', 'period', 'stress_period_data'):
#     Data File: "E:\00_Betami\01_Tutorials_GMDSI_Work_in_Progress\01_Tutorials_Again___\02a_Beta_part0_02_intro_to_freyberg_model\freyberg_mf6\freyberg6.wel_stress_period_data_23.txt:"
#     Pandas Message: "Length of header or names does not match length of data. This leads to a loss of data with index_col=False."
# Pandas warning occurred while loading data ('freyberg6', 'wel', 'period', 'stress_period_data'):
#     Data File: "E:\00_Betami\01_Tutorials_GMDSI_Work_in_Progress\01_Tutorials_Again___\02a_Beta_part0_02_intro_to_freyberg_model\freyberg_mf6\freyberg6.wel_stress_period_data_24.txt:"
#     Pandas Message: "Length of header or names does not match length of data. This leads to a loss of data with index_col=False."
# Pandas warning occurred while loading data ('freyberg6', 'wel', 'period', 'stress_period_data'):
#     Data File: "E:\00_Betami\01_Tutorials_GMDSI_Work_in_Progress\01_Tutorials_Again___\02a_Beta_part0_02_intro_to_freyberg_model\freyberg_mf6\freyberg6.wel_stress_period_data_25.txt:"
#     Pandas Message: "Length of header or names does not match length of data. This leads to a loss of data with index_col=False."
#     loading package rch...
#     loading package ghb...
#     loading package sfr...
#     loading package obs...
#   loading solution package freyberg6...
# mf6.exe

# %% [markdown]
# sim = flopy.mf6.  MFSimulation.load (sim_ws=sim_ws  , verbosity_level=0)
# mm =  flopy.plot. PlotMapView       (model=gwf     , ax=ax, layer=0)

# %%
# _________________________________________________plot_____________________ flopy = gwf
fig = plt.figure(figsize=(3, 3))

ax = fig.add_subplot(1, 1, 1, aspect='equal')

mm = flopy.plot.PlotMapView(model=gwf, ax=ax, layer=0)
mm.plot_grid()
mm.plot_inactive()
mm.plot_bc('ghb')
mm.plot_bc('sfr')
mm.plot_bc('wel');
# Out:
# Pandas warning occurred while loading data ('freyberg6', 'wel', 'period', 'stress_period_data'):
#     Data File: "E:\00_Betami\01_Tutorials_GMDSI_Work_in_Progress\01_Tutorials_Again___\02a_Beta_part0_02_intro_to_freyberg_model\freyberg_mf6\freyberg6.wel_stress_period_data_1.txt:"
#     Pandas Message: "Length of header or names does not match length of data. This leads to a loss of data with index_col=False."
# Pandas warning occurred while loading data ('freyberg6', 'wel', 'period', 'stress_period_data'):
#     Data File: "E:\00_Betami\01_Tutorials_GMDSI_Work_in_Progress\01_Tutorials_Again___\02a_Beta_part0_02_intro_to_freyberg_model\freyberg_mf6\freyberg6.wel_stress_period_data_2.txt:"
#     Pandas Message: "Length of header or names does not match length of data. This leads to a loss of data with index_col=False."
# Pandas warning occurred while loading data ('freyberg6', 'wel', 'period', 'stress_period_data'):
#     Data File: "E:\00_Betami\01_Tutorials_GMDSI_Work_in_Progress\01_Tutorials_Again___\02a_Beta_part0_02_intro_to_freyberg_model\freyberg_mf6\freyberg6.wel_stress_period_data_3.txt:"
#     Pandas Message: "Length of header or names does not match length of data. This leads to a loss of data with index_col=False."
# Pandas warning occurred while loading data ('freyberg6', 'wel', 'period', 'stress_period_data'):
#     Data File: "E:\00_Betami\01_Tutorials_GMDSI_Work_in_Progress\01_Tutorials_Again___\02a_Beta_part0_02_intro_to_freyberg_model\freyberg_mf6\freyberg6.wel_stress_period_data_4.txt:"
#     Pandas Message: "Length of header or names does not match length of data. This leads to a loss of data with index_col=False."
# Pandas warning occurred while loading data ('freyberg6', 'wel', 'period', 'stress_period_data'):
#     Data File: "E:\00_Betami\01_Tutorials_GMDSI_Work_in_Progress\01_Tutorials_Again___\02a_Beta_part0_02_intro_to_freyberg_model\freyberg_mf6\freyberg6.wel_stress_period_data_5.txt:"
#     Pandas Message: "Length of header or names does not match length of data. This leads to a loss of data with index_col=False."
# Pandas warning occurred while loading data ('freyberg6', 'wel', 'period', 'stress_period_data'):
#     Data File: "E:\00_Betami\01_Tutorials_GMDSI_Work_in_Progress\01_Tutorials_Again___\02a_Beta_part0_02_intro_to_freyberg_model\freyberg_mf6\freyberg6.wel_stress_period_data_6.txt:"
#     Pandas Message: "Length of header or names does not match length of data. This leads to a loss of data with index_col=False."
# Pandas warning occurred while loading data ('freyberg6', 'wel', 'period', 'stress_period_data'):
#     Data File: "E:\00_Betami\01_Tutorials_GMDSI_Work_in_Progress\01_Tutorials_Again___\02a_Beta_part0_02_intro_to_freyberg_model\freyberg_mf6\freyberg6.wel_stress_period_data_7.txt:"
#     Pandas Message: "Length of header or names does not match length of data. This leads to a loss of data with index_col=False."
# Pandas warning occurred while loading data ('freyberg6', 'wel', 'period', 'stress_period_data'):
#     Data File: "E:\00_Betami\01_Tutorials_GMDSI_Work_in_Progress\01_Tutorials_Again___\02a_Beta_part0_02_intro_to_freyberg_model\freyberg_mf6\freyberg6.wel_stress_period_data_8.txt:"
#     Pandas Message: "Length of header or names does not match length of data. This leads to a loss of data with index_col=False."
# Pandas warning occurred while loading data ('freyberg6', 'wel', 'period', 'stress_period_data'):
#     Data File: "E:\00_Betami\01_Tutorials_GMDSI_Work_in_Progress\01_Tutorials_Again___\02a_Beta_part0_02_intro_to_freyberg_model\freyberg_mf6\freyberg6.wel_stress_period_data_9.txt:"
#     Pandas Message: "Length of header or names does not match length of data. This leads to a loss of data with index_col=False."
# Pandas warning occurred while loading data ('freyberg6', 'wel', 'period', 'stress_period_data'):
#     Data File: "E:\00_Betami\01_Tutorials_GMDSI_Work_in_Progress\01_Tutorials_Again___\02a_Beta_part0_02_intro_to_freyberg_model\freyberg_mf6\freyberg6.wel_stress_period_data_10.txt:"
#     Pandas Message: "Length of header or names does not match length of data. This leads to a loss of data with index_col=False."
# Pandas warning occurred while loading data ('freyberg6', 'wel', 'period', 'stress_period_data'):
#     Data File: "E:\00_Betami\01_Tutorials_GMDSI_Work_in_Progress\01_Tutorials_Again___\02a_Beta_part0_02_intro_to_freyberg_model\freyberg_mf6\freyberg6.wel_stress_period_data_11.txt:"
#     Pandas Message: "Length of header or names does not match length of data. This leads to a loss of data with index_col=False."
# Pandas warning occurred while loading data ('freyberg6', 'wel', 'period', 'stress_period_data'):
#     Data File: "E:\00_Betami\01_Tutorials_GMDSI_Work_in_Progress\01_Tutorials_Again___\02a_Beta_part0_02_intro_to_freyberg_model\freyberg_mf6\freyberg6.wel_stress_period_data_12.txt:"
#     Pandas Message: "Length of header or names does not match length of data. This leads to a loss of data with index_col=False."
# Pandas warning occurred while loading data ('freyberg6', 'wel', 'period', 'stress_period_data'):
#     Data File: "E:\00_Betami\01_Tutorials_GMDSI_Work_in_Progress\01_Tutorials_Again___\02a_Beta_part0_02_intro_to_freyberg_model\freyberg_mf6\freyberg6.wel_stress_period_data_13.txt:"
#     Pandas Message: "Length of header or names does not match length of data. This leads to a loss of data with index_col=False."
# Pandas warning occurred while loading data ('freyberg6', 'wel', 'period', 'stress_period_data'):
#     Data File: "E:\00_Betami\01_Tutorials_GMDSI_Work_in_Progress\01_Tutorials_Again___\02a_Beta_part0_02_intro_to_freyberg_model\freyberg_mf6\freyberg6.wel_stress_period_data_14.txt:"
#     Pandas Message: "Length of header or names does not match length of data. This leads to a loss of data with index_col=False."
# Pandas warning occurred while loading data ('freyberg6', 'wel', 'period', 'stress_period_data'):
#     Data File: "E:\00_Betami\01_Tutorials_GMDSI_Work_in_Progress\01_Tutorials_Again___\02a_Beta_part0_02_intro_to_freyberg_model\freyberg_mf6\freyberg6.wel_stress_period_data_15.txt:"
#     Pandas Message: "Length of header or names does not match length of data. This leads to a loss of data with index_col=False."
# Pandas warning occurred while loading data ('freyberg6', 'wel', 'period', 'stress_period_data'):
#     Data File: "E:\00_Betami\01_Tutorials_GMDSI_Work_in_Progress\01_Tutorials_Again___\02a_Beta_part0_02_intro_to_freyberg_model\freyberg_mf6\freyberg6.wel_stress_period_data_16.txt:"
#     Pandas Message: "Length of header or names does not match length of data. This leads to a loss of data with index_col=False."
# Pandas warning occurred while loading data ('freyberg6', 'wel', 'period', 'stress_period_data'):
#     Data File: "E:\00_Betami\01_Tutorials_GMDSI_Work_in_Progress\01_Tutorials_Again___\02a_Beta_part0_02_intro_to_freyberg_model\freyberg_mf6\freyberg6.wel_stress_period_data_17.txt:"
#     Pandas Message: "Length of header or names does not match length of data. This leads to a loss of data with index_col=False."
# Pandas warning occurred while loading data ('freyberg6', 'wel', 'period', 'stress_period_data'):
#     Data File: "E:\00_Betami\01_Tutorials_GMDSI_Work_in_Progress\01_Tutorials_Again___\02a_Beta_part0_02_intro_to_freyberg_model\freyberg_mf6\freyberg6.wel_stress_period_data_18.txt:"
#     Pandas Message: "Length of header or names does not match length of data. This leads to a loss of data with index_col=False."
# Pandas warning occurred while loading data ('freyberg6', 'wel', 'period', 'stress_period_data'):
#     Data File: "E:\00_Betami\01_Tutorials_GMDSI_Work_in_Progress\01_Tutorials_Again___\02a_Beta_part0_02_intro_to_freyberg_model\freyberg_mf6\freyberg6.wel_stress_period_data_19.txt:"
#     Pandas Message: "Length of header or names does not match length of data. This leads to a loss of data with index_col=False."
# Pandas warning occurred while loading data ('freyberg6', 'wel', 'period', 'stress_period_data'):
#     Data File: "E:\00_Betami\01_Tutorials_GMDSI_Work_in_Progress\01_Tutorials_Again___\02a_Beta_part0_02_intro_to_freyberg_model\freyberg_mf6\freyberg6.wel_stress_period_data_20.txt:"
#     Pandas Message: "Length of header or names does not match length of data. This leads to a loss of data with index_col=False."
# Pandas warning occurred while loading data ('freyberg6', 'wel', 'period', 'stress_period_data'):
#     Data File: "E:\00_Betami\01_Tutorials_GMDSI_Work_in_Progress\01_Tutorials_Again___\02a_Beta_part0_02_intro_to_freyberg_model\freyberg_mf6\freyberg6.wel_stress_period_data_21.txt:"
#     Pandas Message: "Length of header or names does not match length of data. This leads to a loss of data with index_col=False."
# Pandas warning occurred while loading data ('freyberg6', 'wel', 'period', 'stress_period_data'):
#     Data File: "E:\00_Betami\01_Tutorials_GMDSI_Work_in_Progress\01_Tutorials_Again___\02a_Beta_part0_02_intro_to_freyberg_model\freyberg_mf6\freyberg6.wel_stress_period_data_22.txt:"
#     Pandas Message: "Length of header or names does not match length of data. This leads to a loss of data with index_col=False."
# Pandas warning occurred while loading data ('freyberg6', 'wel', 'period', 'stress_period_data'):
#     Data File: "E:\00_Betami\01_Tutorials_GMDSI_Work_in_Progress\01_Tutorials_Again___\02a_Beta_part0_02_intro_to_freyberg_model\freyberg_mf6\freyberg6.wel_stress_period_data_23.txt:"
#     Pandas Message: "Length of header or names does not match length of data. This leads to a loss of data with index_col=False."
# Pandas warning occurred while loading data ('freyberg6', 'wel', 'period', 'stress_period_data'):
#     Data File: "E:\00_Betami\01_Tutorials_GMDSI_Work_in_Progress\01_Tutorials_Again___\02a_Beta_part0_02_intro_to_freyberg_model\freyberg_mf6\freyberg6.wel_stress_period_data_24.txt:"
#     Pandas Message: "Length of header or names does not match length of data. This leads to a loss of data with index_col=False."
# Pandas warning occurred while loading data ('freyberg6', 'wel', 'period', 'stress_period_data'):
#     Data File: "E:\00_Betami\01_Tutorials_GMDSI_Work_in_Progress\01_Tutorials_Again___\02a_Beta_part0_02_intro_to_freyberg_model\freyberg_mf6\freyberg6.wel_stress_period_data_25.txt:"
#     Pandas Message: "Length of header or names does not match length of data. This leads to a loss of data with index_col=False."

# %%
# _________________________________________________plot_____________________ flopy = gwf
for lay in range(gwf.dis.nlay.array):
    print(f'K in layer {lay+1}:', "{:10.1f}".format(gwf.npf.k.get_data(lay).mean()))
# Out:
# K in layer 1:       11.1

# %%
# _________________________________________________plot____
gwf.npf.k.plot(colorbar=True, mflay=0);
gwf.dis.top.plot(colorbar=True, masked_values=[-1049.99])
gwf.dis.botm.plot(colorbar=True);
# _______________________________________________________
obs_data = pd.read_csv(os.path.join('..','..','models','daily_freyberg_mf6_truth','obs_data.csv'))
obs_data = obs_data.pivot(index='time', columns='site', values='value')
obs_data.head()
# _______________________________________________________

# %% [markdown]
# ### E:\00_Betami\10_Beta_tutorials_GMDSI\Tutorials\02a_Beta_part0_02_intro_to_freyberg_model\02_RMG_Freyberg.xlsx

# %%
# _________________________________________________no____
obs_data = pd.read_csv(os.path.join('..','..','models','daily_freyberg_mf6_truth','obs_data.csv'))
obs_data.head()

# %%
# _________________________________________________no____
for i in gwf.obs:
    print(i.output.obs_names)
sfr_obs = pd.read_csv(os.path.join(sim_ws, 'sfr.csv'))
sfr_obs.head()

# %% [markdown]
# First define ... then plot

# %%
obs_data = pd.read_csv(os.path.join('..','..','models','daily_freyberg_mf6_truth','obs_data.csv'))
obs_data = obs_data.pivot(index='time', columns='site', values='value')                             #___important___Pivot
site = 'GAGE-1'
fig,ax=plt.subplots(1,1)  #_______________________________then plot
obs_data.plot(y=site, ax=ax, label='measured')
sfr_obs.plot(x='time', y=site, ax=ax, label='modelled')
ax.set_title(site);

# %%
# _________________________________________________no____
obs_data = pd.read_csv(os.path.join('..','..','models','daily_freyberg_mf6_truth','obs_data.csv'))
obs_data = obs_data.pivot(index='time', columns='site', values='value')                             #___important___Pivot
obs_data.head()

# %%
# _________________________________________________no____
hds_obs = pd.read_csv(os.path.join(sim_ws, 'heads.csv'))
hds_obs.head()

# %%
# _________________________________________________no____             Pto 1    &     Pto 2   _____ Flopy  ____ site ___hds
for site in ['TRGW-0-26-6','TRGW-0-3-8']:
    fig,ax=plt.subplots(1,1)
    obs_data.plot(y=site, ax=ax, label='measured')
    hds_obs.plot(x='time', y=site, ax=ax, label='modelled')

    ax.set_title(site);

# %%
hdobj = gwf.output.head()
times = hdobj.get_times()
hdobj.plot(mflay=0, colorbar=True, totim=times[-1], masked_values=[1e30]);
